# %%
import pandas as pd

# %%
data = pd.read_csv('./matches - matches.csv')
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# 1  normal           0       Rising Pune Supergiant            0
# 2  normal           0        Kolkata Knight Riders            0
# 3  normal           0              Kings XI Punjab            0
# 4  normal           0  Royal Challengers Bangalore           15
#
#    win_by_wickets player_of_match                                      venue  \
# 0               0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# 1               7       SPD Smith    Maharashtra Cricket Association Stadium
# 2              10         CA Lynn     Saurashtra Cricket Association Stadium
# 3               6      GJ Maxwell                     Holkar Cricket Stadium
# 4               0       KM Jadhav                      M Chinnaswamy Stadium
#
#           umpire1        umpire2  umpire3
# 0     AY Dandekar       NJ Llong      NaN
# 1  A Nand Kishore         S Ravi      NaN
# 2     Nitin Menon      CK Nandan      NaN
# 3    AK Chaudhary  C Shamshuddin      NaN
# 4             NaN            NaN      NaN

# %% [markdown]
# value count use in catagorical data

# %%
data['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
# %pip install "pandas[plot, output-formatting]"
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: pandas[output-formatting,plot] in d:\pythonml\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\pythonml\venv\lib\site-packages (from pandas[output-formatting,plot]) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\pythonml\venv\lib\site-packages (from pandas[output-formatting,plot]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\pythonml\venv\lib\site-packages (from pandas[output-formatting,plot]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\pythonml\venv\lib\site-packages (from pandas[output-formatting,plot]) (2025.1)
# Requirement already satisfied: matplotlib>=3.6.3 in d:\pythonml\venv\lib\site-packages (from pandas[output-formatting,plot]) (3.10.1)
# Requirement already satisfied: jinja2>=3.1.2 in d:\pythonml\venv\lib\site-packages (from pandas[output-formatting,plot]) (3.1.6)
# Requirement already satisfied: tabulate>=0.9.0 in d:\pythonml\venv\lib\site-packages (from pandas[output-formatting,plot]) (0.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\pythonml\venv\lib\site-packages (from jinja2>=3.1.2->pandas[output-formatting,plot]) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\pythonml\venv\lib\site-packages (from matplotlib>=3.6.3->pandas[output-formatting,plot]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\pythonml\venv\lib\site-packages (from matplotlib>=3.6.3->pandas[output-formatting,plot]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\pythonml\venv\lib\site-packages (from matplotlib>=3.6.3->pandas[output-formatting,plot]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\pythonml\venv\lib\site-packages (from matplotlib>=3.6.3->pandas[output-formatting,plot]) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\pythonml\venv\lib\site-packages (from matplotlib>=3.6.3->pandas[output-formatting,plot]) (24.2)
# Requirement already satisfied: pillow>=8 in d:\pythonml\venv\lib\site-packages (from matplotlib>=3.6.3->pandas[output-formatting,plot]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\pythonml\venv\lib\site-packages (from matplotlib>=3.6.3->pandas[output-formatting,plot]) (3.2.1)
# Requirement already satisfied: six>=1.5 in d:\pythonml\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas[output-formatting,plot]) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
data['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
data['winner'].value_counts().head().plot(kind='barh')
# Out:
# <Axes: ylabel='winner'>

# %%
data['toss_decision'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data['win_by_runs'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['win_by_runs'].plot(kind='line')
# Out:
# <Axes: >

# %%
data['win_by_runs'].plot(kind='pie')
# Out:
# <Axes: ylabel='win_by_runs'>
