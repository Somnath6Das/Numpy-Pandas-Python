# %%
import pandas as pd

# %% [markdown]
# <h5>Working with Json</h5>

# %%
recipes= pd.read_json("./recipes.json");
recipes.head(2)
# Out:
#                            Name  \
# 0                 Christmas pie
# 1  Simmer-&-stir Christmas cake
#
#                                                  url  \
# 0  https://www.bbcgoodfood.com/recipes/2793/chris...
# 1  https://www.bbcgoodfood.com/recipes/1160/simme...
#
#                                          Description        Author  \
# 0  Combine a few key Christmas flavours here to m...  Mary Cadogan
# 1  An easy-to-make alternative to traditional Chr...  Mary Cadogan
#
#                                          Ingredients  \
# 0  [2 tbsp olive oil, knob butter, 1 onion, finel...
# 1  [175g butter, chopped, 200g dark muscovado sug...
#
#                                               Method
# 0  [Heat oven to 190C/fan 170C/gas 5. Heat 1 tbsp...
# 1  [Put the butter, sugar, fruit, zests, juice an...

# %%
recipes1=pd.read_json("https://api.exchangerate-api.com/v4/latest/INR")
recipes1.head(2)
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# INR  https://www.exchangerate-api.com/terms  INR 2025-04-04
# AED  https://www.exchangerate-api.com/terms  INR 2025-04-04
#
#      time_last_updated  rates
# INR         1743724802  1.000
# AED         1743724802  0.043

# %% [markdown]
# <h5>Working with SQL</h5>

# %%
# %pip install mysql.connector
import mysql.connector as mysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
country = mysql.connect(host="localhost", user="root", password="", database="world")

# %%
pd.read_sql_query("SELECT * FROM country", country).head(2)
# Out:
# C:\Users\Som\AppData\Local\Temp\ipykernel_9876\338096865.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country", country).head(2)
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
#
#                LocalName                                GovernmentForm  \
# 0                  Aruba  Nonmetropolitan Territory of The Netherlands
# 1  Afganistan/Afqanestan                               Islamic Emirate
#
# ...

# %%
pd.read_sql_query("SELECT * FROM city WHERE countryCode LIKE 'USA'", country)
# Out:
# C:\Users\Som\AppData\Local\Temp\ipykernel_9876\2334491369.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE countryCode LIKE 'USA'", country)
#        ID          Name CountryCode        District  Population
# 0    3793      New York         USA        New York     8008278
# 1    3794   Los Angeles         USA      California     3694820
# 2    3795       Chicago         USA        Illinois     2896016
# 3    3796       Houston         USA           Texas     1953631
# 4    3797  Philadelphia         USA    Pennsylvania     1517550
# ..    ...           ...         ...             ...         ...
# 269  4062       Kenosha         USA       Wisconsin       89447
# 270  4063         Elgin         USA        Illinois       89408
# ...

# %%
pd.read_sql_query("SELECT * FROM country WHERE LifeExpectancy > 60", country)
# Out:
# C:\Users\Som\AppData\Local\Temp\ipykernel_9876\1079616369.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country WHERE LifeExpectancy > 60", country)
#     Code                  Name      Continent           Region  SurfaceArea  \
# 0    ABW                 Aruba  North America        Caribbean        193.0
# 1    AIA              Anguilla  North America        Caribbean         96.0
# 2    ALB               Albania         Europe  Southern Europe      28748.0
# 3    AND               Andorra         Europe  Southern Europe        468.0
# 4    ANT  Netherlands Antilles  North America        Caribbean        800.0
# ..   ...                   ...            ...              ...          ...
# 162  VIR  Virgin Islands, U.S.  North America        Caribbean        347.0
# ...

# %%
df = pd.read_sql_query("SELECT * FROM countrylanguage ", country)
df
# Out:
# C:\Users\Som\AppData\Local\Temp\ipykernel_9876\1625161551.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM countrylanguage ", country)
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]
